# %% [markdown]
# # Gojek Bootcamp Kaggle Challenge 2019
# ## Fake GPS Detection
# #### By Claudius Devlin Halimi

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567545 entries, 0 to 567544
# Data columns (total 11 columns):
# order_id              567545 non-null object
# service_type          567545 non-null object
# driver_status         567545 non-null object
# date                  567545 non-null object
# hour                  567545 non-null int64
# seconds               567545 non-null int64
# latitude              567545 non-null float64
# longitude             567545 non-null float64
# altitude_in_meters    413142 non-null float64
# accuracy_in_meters    567545 non-null float64
# label                 567545 non-null int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 47.6+ MB

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_train.corr(), annot=True)

# %% [markdown]
# There are some missing data on altitude_in_meters. So we are going to fill it with another feature. As we can see, the heatmap correlation shows that altitude is quite related with latitude and longitude. Because of that, we will use two of those feature to fill mising data from altitude with decision tree regressor.

# %% [markdown]
# # Filling the missing data using decision tree regressor

# %%
# not null altitude
df_train_nonull=df_train[~df_train['altitude_in_meters'].isna()]
df_train_nonull
# Out:
#        order_id service_type driver_status        date  hour     seconds  \
# 1         RB193      GO_RIDE     AVAILABLE  2018-02-05     6  1548890680
# 2         RB193      GO_RIDE     AVAILABLE  2018-02-05     6  1548890690
# 3         RB193      GO_RIDE     AVAILABLE  2018-02-05     6  1548890700
# 4         RB193      GO_RIDE     AVAILABLE  2018-02-05     6  1548890710
# 5         RB193      GO_RIDE     AVAILABLE  2018-02-05     6  1548890720
# ...         ...          ...           ...         ...   ...         ...
# 567540    RB261      GO_RIDE   OTW_DROPOFF  2018-03-22    13  1552803198
# 567541    RB261      GO_RIDE   OTW_DROPOFF  2018-03-22    13  1552803208
# 567542    RB261      GO_RIDE   OTW_DROPOFF  2018-03-22    13  1552803218
# 567543    RB261      GO_RIDE   OTW_DROPOFF  2018-03-22    13  1552803228
# 567544    RB261      GO_RIDE   OTW_DROPOFF  2018-03-22    13  1552803238
#
#         latitude   longitude  altitude_in_meters  accuracy_in_meters  label
# 1      -6.923039  107.631250          712.000000               9.577      0
# 2      -6.923039  107.631250          712.000000               9.577      0
# 3      -6.923048  107.631230          713.000000               8.139      0
# 4      -6.922968  107.631253          713.000000               7.029      0
# 5      -6.922968  107.631253          713.000000               7.029      0
# ...          ...         ...                 ...                 ...    ...
# 567540 -6.889018  107.595516          798.799988              21.381      1
# 567541 -6.889020  107.595516          798.799988              19.621      1
# 567542 -6.889017  107.595526          798.799988              18.012      1
# 567543 -6.889017  107.595526          798.799988              18.012      1
# 567544 -6.889015  107.595528          798.799988              17.791      1
#
# [413142 rows x 11 columns]

# %% [markdown]
# ### Train Data

# %%
fitur=df_train[~df_train['altitude_in_meters'].isna()][['latitude','longitude']]
hasil=df_train[~df_train['altitude_in_meters'].isna()]['altitude_in_meters']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(fitur, hasil, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor
hutan=DecisionTreeRegressor()
hutan.fit(x_train, y_train)
hutan_predict=hutan.predict(x_test)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, hutan_predict))
print('MSE:', metrics.mean_squared_error(y_test, hutan_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, hutan_predict)))
# Out:
# MAE: 10.868188233206727
# MSE: 2561.9156540471417
# RMSE: 50.61536974128651

# %%
hasil.describe()
# Out:
# count    413142.000000
# mean        744.885056
# std         105.357303
# min       -1075.000000
# 25%         708.300000
# 50%         748.400000
# 75%         790.481659
# max        4674.877000
# Name: altitude_in_meters, dtype: float64

# %% [markdown]
# We can see the MAE is quite small compared to the altitude data. and the RMSE is small also. So we can use this model to fill the missing altitude data.

# %%
fill=DecisionTreeRegressor()
fill.fit(fitur, hasil)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from tqdm import tqdm 

kosong=df_train[df_train['altitude_in_meters'].isna()].index
for i in tqdm(kosong):
    df_train.loc[i,'altitude_in_meters']=fill.predict(np.array(df_train.loc[i,['latitude','longitude']]).reshape(1,-1)).item()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 154403/154403 [22:27<00:00, 114.61it/s]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567545 entries, 0 to 567544
# Data columns (total 11 columns):
# order_id              567545 non-null object
# service_type          567545 non-null object
# driver_status         567545 non-null object
# date                  567545 non-null object
# hour                  567545 non-null int64
# seconds               567545 non-null int64
# latitude              567545 non-null float64
# longitude             567545 non-null float64
# altitude_in_meters    567545 non-null float64
# accuracy_in_meters    567545 non-null float64
# label                 567545 non-null int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 47.6+ MB

# %% [markdown]
# ### Test Data

# %%
test_feature=df_test[~df_test['altitude_in_meters'].isna()][['latitude','longitude']]
test_hasil=df_test[~df_test['altitude_in_meters'].isna()]['altitude_in_meters']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(test_feature, test_hasil, test_size=0.3)

# %%
isi=DecisionTreeRegressor()
isi.fit(X_train, Y_train)
fill_test=isi.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, hutan_predict))
print('MSE:', metrics.mean_squared_error(y_test, hutan_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, hutan_predict)))
# Out:
# MAE: 10.868188233206727
# MSE: 2561.9156540471417
# RMSE: 50.61536974128651

# %%
test_hasil.describe()
# Out:
# count    60131.000000
# mean       741.812725
# std        104.837232
# min       -181.000000
# 25%        708.600000
# 50%        745.000000
# 75%        788.300000
# max       1078.000000
# Name: altitude_in_meters, dtype: float64

# %% [markdown]
# We can see evaluation model for test data is as good as the train data. So we are gonna use the same model but using the test data

# %%
fill.fit(test_feature, test_hasil)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
#Test data
from tqdm import tqdm

empty=df_test[df_test['altitude_in_meters'].isna()].index
for i in tqdm(empty):
    df_test.loc[i,'altitude_in_meters']=fill.predict(np.array(df_test.loc[i,['latitude','longitude']]).reshape(1,-1)).item()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 21203/21203 [00:58<00:00, 360.91it/s]

# %% [markdown]
# # Predicting the label for each user.
#
# Because we have to predict the label for each order_id, so we're going to group the data y the order id and then we aggregate the grouping data with sum, min, max, mean, median, and std. The feature that we are going to use to predict the label is seconds, latitude, longitude, altitude, and accuracy. The prediction model that we are going to use is random forest classifier

# %%
train=df_train[['order_id','seconds','latitude','longitude','altitude_in_meters','accuracy_in_meters','label']].groupby('order_id').agg(['sum','min','max','mean','median','std'])
test=df_test[['order_id','seconds','latitude','longitude','altitude_in_meters','accuracy_in_meters']].groupby('order_id').agg(['sum','min','max','mean','median','std'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3500 entries, F0 to RB999
# Data columns (total 36 columns):
# (seconds, sum)                  3500 non-null int64
# (seconds, min)                  3500 non-null int64
# (seconds, max)                  3500 non-null int64
# (seconds, mean)                 3500 non-null float64
# (seconds, median)               3500 non-null float64
# (seconds, std)                  3498 non-null float64
# (latitude, sum)                 3500 non-null float64
# (latitude, min)                 3500 non-null float64
# (latitude, max)                 3500 non-null float64
# (latitude, mean)                3500 non-null float64
# (latitude, median)              3500 non-null float64
# (latitude, std)                 3498 non-null float64
# (longitude, sum)                3500 non-null float64
# (longitude, min)                3500 non-null float64
# (longitude, max)                3500 non-null float64
# (longitude, mean)               3500 non-null float64
# (longitude, median)             3500 non-null float64
# (longitude, std)                3498 non-null float64
# (altitude_in_meters, sum)       3500 non-null float64
# (altitude_in_meters, min)       3500 non-null float64
# (altitude_in_meters, max)       3500 non-null float64
# (altitude_in_meters, mean)      3500 non-null float64
# (altitude_in_meters, median)    3500 non-null float64
# (altitude_in_meters, std)       3498 non-null float64
# (accuracy_in_meters, sum)       3500 non-null float64
# (accuracy_in_meters, min)       3500 non-null float64
# (accuracy_in_meters, max)       3500 non-null float64
# (accuracy_in_meters, mean)      3500 non-null float64
# (accuracy_in_meters, median)    3500 non-null float64
# (accuracy_in_meters, std)       3498 non-null float64
# (label, sum)                    3500 non-null int64
# (label, min)                    3500 non-null int64
# (label, max)                    3500 non-null int64
# (label, mean)                   3500 non-null int64
# (label, median)                 3500 non-null int64
# (label, std)                    3498 non-null float64
# dtypes: float64(28), int64(8)
# memory usage: 1011.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, F10 to RB993
# Data columns (total 30 columns):
# (seconds, sum)                  500 non-null int64
# (seconds, min)                  500 non-null int64
# (seconds, max)                  500 non-null int64
# (seconds, mean)                 500 non-null float64
# (seconds, median)               500 non-null float64
# (seconds, std)                  500 non-null float64
# (latitude, sum)                 500 non-null float64
# (latitude, min)                 500 non-null float64
# (latitude, max)                 500 non-null float64
# (latitude, mean)                500 non-null float64
# (latitude, median)              500 non-null float64
# (latitude, std)                 500 non-null float64
# (longitude, sum)                500 non-null float64
# (longitude, min)                500 non-null float64
# (longitude, max)                500 non-null float64
# (longitude, mean)               500 non-null float64
# (longitude, median)             500 non-null float64
# (longitude, std)                500 non-null float64
# (altitude_in_meters, sum)       500 non-null float64
# (altitude_in_meters, min)       500 non-null float64
# (altitude_in_meters, max)       500 non-null float64
# (altitude_in_meters, mean)      500 non-null float64
# (altitude_in_meters, median)    500 non-null float64
# (altitude_in_meters, std)       500 non-null float64
# (accuracy_in_meters, sum)       500 non-null float64
# (accuracy_in_meters, min)       500 non-null float64
# (accuracy_in_meters, max)       500 non-null float64
# (accuracy_in_meters, mean)      500 non-null float64
# (accuracy_in_meters, median)    500 non-null float64
# (accuracy_in_meters, std)       500 non-null float64
# dtypes: float64(27), int64(3)
# memory usage: 121.1+ KB

# %% [markdown]
# There are some order_id that only have 1 order, that means the std is 0. But on when we grouped and aggregated the table, the value becomes Nan. So, we are going to fill the nan with 0.

# %%
data_train, data_test, target_train, target_test=train_test_split(train.drop(columns='label'), train['label']['min'], test_size=0.3)
train.fillna(0, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, F10 to RB993
# Data columns (total 30 columns):
# (seconds, sum)                  500 non-null int64
# (seconds, min)                  500 non-null int64
# (seconds, max)                  500 non-null int64
# (seconds, mean)                 500 non-null float64
# (seconds, median)               500 non-null float64
# (seconds, std)                  500 non-null float64
# (latitude, sum)                 500 non-null float64
# (latitude, min)                 500 non-null float64
# (latitude, max)                 500 non-null float64
# (latitude, mean)                500 non-null float64
# (latitude, median)              500 non-null float64
# (latitude, std)                 500 non-null float64
# (longitude, sum)                500 non-null float64
# (longitude, min)                500 non-null float64
# (longitude, max)                500 non-null float64
# (longitude, mean)               500 non-null float64
# (longitude, median)             500 non-null float64
# (longitude, std)                500 non-null float64
# (altitude_in_meters, sum)       500 non-null float64
# (altitude_in_meters, min)       500 non-null float64
# (altitude_in_meters, max)       500 non-null float64
# (altitude_in_meters, mean)      500 non-null float64
# (altitude_in_meters, median)    500 non-null float64
# (altitude_in_meters, std)       500 non-null float64
# (accuracy_in_meters, sum)       500 non-null float64
# (accuracy_in_meters, min)       500 non-null float64
# (accuracy_in_meters, max)       500 non-null float64
# (accuracy_in_meters, mean)      500 non-null float64
# (accuracy_in_meters, median)    500 non-null float64
# (accuracy_in_meters, std)       500 non-null float64
# dtypes: float64(27), int64(3)
# memory usage: 121.1+ KB

# %%
from sklearn.ensemble import RandomForestClassifier

data_train.fillna(0, inplace=True)
data_test.fillna(0, inplace=True)

model=RandomForestClassifier()
model.fit(data_train, target_train)
label=model.predict(data_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(target_test, label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       313
#            1       0.91      0.89      0.90       737
#
#     accuracy                           0.87      1050
#    macro avg       0.84      0.85      0.84      1050
# weighted avg       0.87      0.87      0.87      1050

# %% [markdown]
# Alright, this is good. The accuracy score is 87% and the precision and recall is not bad. We can see here that the model can recognize a fake gps more. That means some order that is not fake can be recognized as a fake and that is not cool. But the model also can predict not fake order quite well, the precision and recall is not as good as the fake one. But I can bare with that.

# %% [markdown]
# # Alright let's predict the test data
# Because the label can be either 1 or 0 so I use the min aggregate label, since each order can only have one label. It doesn't matter if we use any aggregate feature. As long as we don't use the std because it's always 0.

# %%
model.fit(train.drop(columns='label'), train['label']['min'])
predict=model.predict(test)
final=pd.DataFrame(zip(test.index,predict), columns=['order_id','label'])

# %%
final
# Out:
#     order_id  label
# 0        F10      0
# 1      F1008      0
# 2      F1011      1
# 3      F1022      1
# 4       F103      1
# ..       ...    ...
# 495    RB926      0
# 496    RB928      0
# 497    RB955      0
# 498    RB976      1
# 499    RB993      0
#
# [500 rows x 2 columns]

# %%
final.to_csv('')

# %%
pd.read_csv('sample_submission.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5ba6c669d75> in <module>
# ----> 1 pd.read_csv('sample_submission.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# And here we go, I really want to compared my answer to the real answer. But I can't find any resource that have the real answer. But I do compared it to the answers on the kernels and I'm happy with my answer. Thank you hope this will help you guys.

# %% [markdown]
# # Thank You
